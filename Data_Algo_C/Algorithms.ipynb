# %% [markdown]
# # 1. Newton-Raphson Method

# %% [markdown]
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# $x_1=x_0-f(x_0)/f'(x_0)$
#
# $f(x)=x^2-a$
#
# $f'(x)=2x$
#
# $x_1=x_0- \frac{x_0^2-a}{2 x_0}=\frac{1}{2}x_0+\frac{a}{2x_0}$
#
#
# https://blog.csdn.net/zhaoyunfullmetal/article/details/49281843
